# %%
import whisper
import openai
#import ffmpeg
openai.api_key='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'
model = whisper.load_model("medium")
result = model.transcribe("/Users/hanshan/Downloads/重大主线投资，中特估一带一路：强推三标的 20230413.mp3")#,fp16=False
print(result["text"])
# Out:
# /Users/hanshan/Library/Python/3.9/lib/python/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

def save_string_to_pdf(text, output_path):
    c = canvas.Canvas(output_path, pagesize=letter)
    c.setFont("Helvetica", 12)
    #text_lines = text.split("\n")

    x = 50
    y = 750

    #for line in text_lines:
    #    c.drawString(x, y, line)
    #    y -= 15

    c.save()

# Example usage
#text = "Hello, this is a sample string.\nThis is a new line."
output_path = "output.pdf"

save_string_to_pdf(result, output_path)

# %%
import openai
openai.api_key='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'
#openai.Model.list()
print(result)
# Out:
# {'text': '本次會議緊面向開源證券的專業投資機構客戶或受邀客戶僅供在新媒體背景下研究觀點的即時交流第三方專家發言內容僅代表其個人觀點所有信息或所表述的意見並不構成對任何人的投資建議未經開源證券事先書面許可任何機構或個人延期錄音、轉發及相關解讀涉嫌違反上述情形的我們將保留一切法律權利感謝您的理解和支持謝謝各位朋友大家晚上好那麼又到了我們開源一席談時間我們看到今天整個市場這個半導體板塊它其實是有所回落的那麼不少跟AI有關的一些概念股呢其實今天的跌幅也比較大那麼很多投資者對今年以來即使如何那個TMT牛市行情是否出現階段性的拐點產生了一定的擔憂那麼今天我們邀請到了我們的老朋友廣發基金信息技術ETF基金經理霍華銘霍總那麼請他給我們聊聊他對於今年以來信息技術及半導體的一個看法那麼歡迎霍總各位大家好我是廣發基金指數投資部的基金經理霍華銘霍總那我們看到其實去年整個一個半導體或者說電子行業它的一個表現是處於一個行業中一個相對墊底的一個位置但是今年以來它的表現卻非常的亮眼那麼首先請霍總給我們復盤一下整個一個半導體它這兩年的一個整體表現及背後的一個原因好的半導體其實是一個假如從長維度去看它是一個成長行業來的我們想像一下從當年的一個PC再到手機再到智能汽車再到現在的人工智能半導體的一個需求的一個場景應該是越來越多使用的人也是越來越多所以我們從長期的角度來看半導體是一個成長的行業但是從一個短周期的角度去看它又是個周期行業比如說我們從三年到四年的維度去看半導體半導體又是一個周期性的行業我們其實可以把這個稱作為庫存的一個周期那麼過去幾年我們看到半導體是發生了一波比較大的一個行情那麼主要是發生了兩件事情第一件就是像我們的這種智能穿戴產品的需求的爆發特別在2019年2020年那個爆發直接帶動了半導體的一個需求另外一個原因是因為由於疫情的原因所以導致了在家辦公的一個需求也是增加了所以手機還有電腦這些終端的一個需求也是快速的一個增長但是我們要知道就是需求是增長的但是整個半導體的一些製造商他擴充產能是需要時間的大概需要一年多的時間從他建廠再買設備再調適然後再去購買材料所花的時間都挺長的所以我們就可以看到這種情形在需求快速爆發的時候它的產能是跟不上來的到了後面的時候它的一個供不應求是越來越厲害所以我們看到整個芯片的半導體的價格是在這幾年是不斷的一個上漲現在已經是到了什麼階段呢已經是到了擴充產能完
# ...
